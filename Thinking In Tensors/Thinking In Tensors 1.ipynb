# %% [markdown]
# <a href="https://colab.research.google.com/github/Alymostafa/GPA_Prediction/blob/master/Thinking%20In%20Tensors%201.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##Imports

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sb
import numpy.ma as ma

# %%
data=pd.read_csv('DATA1.csv')

# %% [markdown]
# ##Display all Data

# %%
def display_all(data):
    with pd.option_context("display.max_rows", 1000, "display.max_columns", 1000): 
        display(data)

# %% [markdown]
# ##Assign Features and Labeles

# %%
data1=(data-data.mean())/data.std()
x_1 = data[['Per_min_OnRoad','Per_hours_At_College','Per_days_attendance']]

X_1 = np.array(x_1)
y_1 = data[['GPA :']]
y_1.head()
Y_1 = np.array(y_1)

# %% [markdown]
# ##Visualize Data

# %%
sb.pairplot(data)

# %%
import matplotlib as mpl 
from mpl_toolkits.mplot3d import Axes3D 
fig = plt.figure() 
ax = fig.gca(projection ='3d') 
  
ax.scatter(X_1[:, 0], X_1[:, 1],X_1[:,2], label ='y', s =5) 
ax.legend() 
ax.view_init(45, 0) 
  
plt.show()

# %% [markdown]
# ##<h2>Covariance Matrix and Mean

# %%
cov=np.cov(X_1,y=None, rowvar=False, bias=False, ddof=None, fweights=None, aweights=None)
mean=np.mean(X_1,axis=0)

# %% [markdown]
# ##Generating New Data from Old Distribution Data

# %%
Size_of_Data=500
New_Data= np.random.multivariate_normal(mean, cov,Size_of_Data)
New_Data.shape
# Out:
# (500, 3)

# %% [markdown]
# ##<h3 color='red'> Ploting Old Data and New Data</h3>

# %%
New_Data[New_Data < 0] = 0
plt.plot(x_1,color='blue')
plt.plot(New_Data,color='r')
plt.show()

# %% [markdown]
# ##This Function Delete rows whose Values = 0

# %%
#Function Clean Data Whose Values Are 0
def Delete_Zeros(New_Data):
  index=[]
  for i in New_Data :
    if np.count_nonzero(i == 0) > 0 or np.count_nonzero(i ==( 0)):
        index.append(np.where(np.all(New_Data==i,axis=1))[0][0])
  cleaned_data=np.delete(New_Data,index,0) 
  return cleaned_data

Cleaned_data1=Delete_Zeros(New_Data)

# %%
#function Delete rows whose values >6 Days
def constrains_per_day(cleaned_data1):
  x=[]
  for i in range(len(cleaned_data1)):
    if cleaned_data1[i][2]>6:
      x.append(i)  
  cleaned_data2=np.delete(cleaned_data1,x,0)
  return cleaned_data2
Cleaned_data2=constrains_per_day(Cleaned_data1)

# %%
#This function delete rows whose Values >10 hours
def constrains_per_hours(Cleaned_data2):
  x=[]
  for i in range(len(Cleaned_data2)):
    if Cleaned_data2[i][1]>10:
      x.append(i)  
  cleaned_data3=np.delete(Cleaned_data2,x,0)
  return cleaned_data3

Cleaned_data3=constrains_per_hours(Cleaned_data2)

# %%
#This function delete rows whose values <5 min and >300 min
def constrains_per_min_Road(Cleaned_data3):
  x=[]
  for i in range(len(Cleaned_data3)):
    if Cleaned_data3[i][0]<5 or Cleaned_data3[i][0]>300:
      x.append(i)  
  cleaned_data4=np.delete(Cleaned_data3,x,0)
  return cleaned_data4

Final_Data=constrains_per_min_Road(Cleaned_data3)

# %% [markdown]
# ##<h1 color="blue">Ploting The New Data After Cleaning and Old Data</h1>

# %%
# The New Data Represented by red Color 
plt.plot(Final_Data,color='r')
plt.plot(data,color='blue')
plt.show()

# %% [markdown]
# ##<h1>The Percentage of data After Cleaning</h1>

# %%
Size_After_cleaning=Final_Data.shape[0]
def Percentage_Of_Cleaning(Size_of_Data,Size_After_cleaning):
   result=((Size_of_Data-Size_After_cleaning)/Size_of_Data)*100
   print(result)
Percentage_Of_Cleaning(Size_of_Data,Size_After_cleaning)
# Out:
# 14.2

# %% [markdown]
# ##<h1>KNN For Testing Distance between two classes</h1>

# %%
ones=np.ones(242)

# %%
shape = Final_Data.shape[0]
shape
# Out:
# 457

# %%
zeros=np.zeros(shape)
# column_to_be_added_zeros = np.array(zeros)
# class_zeros = np.column_stack((X, column_to_be_added_zeros))
# class_zeros

# %%
Merge_data=np.concatenate((X_1, Final_Data), axis=0)
Y_label=np.concatenate((ones,zeros),axis=0)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(Merge_data,Y_label, test_size=0.2) # change test_size and no of features

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
scaler.fit(X_train)

X_train = scaler.transform(X_train)
X_test = scaler.transform(X_test)

# %%
from sklearn.neighbors import KNeighborsClassifier
classifier = KNeighborsClassifier(n_neighbors=100)
classifier.fit(X_train, y_train)
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#                      metric_params=None, n_jobs=None, n_neighbors=100, p=2,
#                      weights='uniform')

# %%
from sklearn import metrics

y_pred = classifier.predict(X_test)
print(metrics.accuracy_score( y_pred,y_test))
# Out:
# 0.6142857142857143

# %%
from sklearn.metrics import classification_report, confusion_matrix
print(confusion_matrix(y_test, y_pred))
print(classification_report(y_pred,y_test))
# Out:
# [[86  0]
#  [54  0]]
#               precision    recall  f1-score   support
#
#          0.0       1.00      0.61      0.76       140
#          1.0       0.00      0.00      0.00         0
#
#     accuracy                           0.61       140
#    macro avg       0.50      0.31      0.38       140
# weighted avg       1.00      0.61      0.76       140
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/classification.py:1439: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples.
#   'recall', 'true', average, warn_for)

# %%
error = []

# Calculating error for K values between 1 and 40
for i in range(1, 40):
    knn = KNeighborsClassifier(n_neighbors=i)
    knn.fit(X_train, y_train)
    pred_i = knn.predict(X_test)
    error.append(np.mean(pred_i != y_test))

# %%
plt.figure(figsize=(12, 6))
plt.plot(range(1, 40), error, color='red', linestyle='dashed', marker='o',
         markerfacecolor='blue', markersize=10)
plt.title('Error Rate K Value')
plt.xlabel('K Value')
plt.ylabel('Mean Error')
# Out:
# Text(0, 0.5, 'Mean Error')

# %% [markdown]
# ##<h1>categoreis GPA</h1>

# %%
def gpa_cat(data):
  data = np.where((data >= 2.0 ) & (data < 2.4),-2,data) #pass
  data = np.where((data < 2.0) & (data >= 1.0),-1,data) #fail
  data = np.where(data>=3.4,0,data)#excellent
  data = np.where((data >= 2.8) & (data < 3.4),1,data)#very good
  data = np.where((data >= 2.4) & (data < 2.8),2,data)#good
  data_1 = data.astype(int)
  return data_1
print(gpa_cat(Y_1))
# Out:
# [[-2]
#  [ 1]
#  [ 1]
#  [ 0]
#  [ 1]
#  [ 1]
#  [ 1]
#  [ 2]
#  [ 0]
#  [ 2]
#  [ 2]
#  [ 2]
#  [-2]
#  [ 0]
#  [ 2]
#  [ 1]
#  [ 2]
#  [ 1]
#  [ 2]
#  [ 1]
#  [ 1]
#  [ 1]
#  [ 1]
#  [ 2]
#  [ 1]
#  [ 1]
#  [ 0]
#  [ 1]
#  [ 2]
#  [ 1]
#  [-2]
#  [ 1]
#  [ 2]
#  [ 1]
#  [ 0]
#  [ 2]
#  [ 2]
#  [ 2]
#  [ 1]
#  [ 1]
#  [ 2]
#  [ 1]
#  [ 1]
#  [ 2]
#  [ 2]
#  [ 1]
#  [-2]
#  [ 1]
#  [ 2]
#  [ 1]
#  [ 2]
#  [ 2]
#  [-2]
#  [ 1]
#  [ 0]
#  [ 1]
#  [ 1]
#  [ 1]
#  [ 1]
#  [ 2]
#  [ 1]
#  [ 2]
#  [ 1]
#  [ 1]
#  [ 1]
#  [ 1]
#  [ 2]
#  [ 1]
#  [ 2]
#  [ 1]
#  [ 1]
#  [-2]
#  [ 2]
#  [ 2]
#  [ 2]
#  [ 1]
#  [ 2]
#  [ 2]
#  [ 1]
#  [ 1]
#  [ 2]
#  [ 1]
#  [-2]
#  [-2]
#  [ 2]
#  [-1]
#  [ 2]
#  [-2]
#  [ 2]
#  [ 2]
#  [ 1]
#  [ 1]
#  [ 1]
#  [ 1]
#  [-2]
#  [ 1]
#  [ 2]
#  [ 2]
#  [ 1]
#  [ 1]
#  [ 2]
#  [ 2]
#  [ 2]
#  [ 0]
#  [ 2]
#  [ 2]
#  [ 1]
#  [-2]
#  [ 1]
#  [ 2]
#  [ 0]
#  [ 1]
#  [ 1]
#  [ 1]
#  [ 1]
#  [ 1]
#  [ 0]
#  [ 1]
#  [ 2]
#  [ 1]
#  [ 1]
#  [ 1]
#  [ 2]
#  [ 1]
#  [ 2]
#  [ 2]
#  [ 2]
#  [ 2]
#  [ 1]
#  [ 1]
#  [ 1]
#  [ 2]
#  [ 2]
#  [ 1]
#  [ 1]
#  [ 1]
#  [ 2]
#  [ 1]
#  [ 2]
#  [ 2]
#  [ 1]
#  [ 2]
#  [ 2]
#  [ 2]
#  [ 0]
#  [ 1]
#  [-2]
#  [ 1]
#  [ 0]
#  [ 0]
#  [ 1]
#  [ 2]
#  [ 1]
#  [-2]
#  [ 2]
#  [ 2]
#  [ 1]
#  [-2]
#  [ 1]
#  [-2]
#  [ 2]
#  [ 1]
#  [ 0]
#  [-2]
#  [ 2]
#  [ 1]
#  [ 1]
#  [ 1]
#  [ 1]
#  [ 1]
#  [ 1]
#  [ 0]
#  [ 2]
#  [ 2]
#  [ 1]
#  [ 2]
#  [ 1]
#  [ 1]
#  [ 0]
#  [ 2]
#  [ 1]
#  [ 1]
#  [-2]
#  [ 2]
#  [ 1]
#  [ 1]
#  [ 1]
#  [-2]
#  [ 1]
#  [ 1]
#  [ 2]
#  [ 2]
#  [ 1]
#  [ 2]
#  [-1]
#  [ 1]
#  [ 0]
#  [ 2]
#  [ 2]
#  [ 2]
#  [-2]
#  [ 1]
#  [ 1]
#  [ 1]
#  [ 1]
#  [ 1]
#  [ 1]
#  [ 1]
#  [ 1]
#  [ 2]
#  [ 1]
#  [-2]
#  [ 1]
#  [ 2]
#  [ 1]
#  [ 1]
#  [ 2]
#  [ 1]
#  [ 1]
#  [ 1]
#  [ 0]
#  [ 1]
#  [ 1]
#  [ 0]
#  [ 0]
#  [ 1]
#  [ 1]
#  [-2]
#  [ 1]
#  [-2]
#  [-2]
#  [ 1]
#  [ 0]
#  [ 1]
#  [-2]
#  [-1]
#  [ 0]
#  [ 1]
#  [ 2]
#  [ 2]
#  [ 2]
#  [ 1]]

# %% [markdown]
# ## Prototype Linear Regression Without Normlization and Category

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn import metrics

# %%
X_train, X_test, y_train, y_test = train_test_split(x_1, y_1, test_size=0.2, random_state=0)

# %%
regressor = LinearRegression()
regressor.fit(X_train, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
y_pred = regressor.predict(X_test)

# %%
from sklearn import metrics
print('Mean Absolute Error:', metrics.mean_absolute_error(y_test, y_pred))
print('Mean Squared Error:', metrics.mean_squared_error(y_test, y_pred))
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(y_test, y_pred)))
# Out:
# Mean Absolute Error: 0.347916237245642
# Mean Squared Error: 0.20058383518005063
# Root Mean Squared Error: 0.44786586739787465

# %%
#f = X_train1[:,0]
#plt.scatter(f, y_train1,color='g')
#y_pred1.shape
#plt.plot(f, y_train1,color='r')

# %%
Reg_coef=regressor.coef_
Reg_inte=regressor.intercept_

# %%
#for i in range (35):
 # print(y_test1[i])
  #print("--------------")
  #print(y_pred1[i])

# %% [markdown]
# ##Linear Regression With Normalization and Category

# %%
data1=(data-data.mean())/data.std()
x_1 = data[['Per_min_OnRoad','Per_hours_At_College','Per_days_attendance']]

X_1 = np.array(x_1)
y_1 = data[['GPA :']]
y_1.head()
Y_1 = np.array(y_1)

# %%
 Y_label=gpa_cat(Y_1)
X_train, X_test, y_train, y_test = train_test_split(x_1, Y_label, test_size=0.2, random_state=0)

# %%
regressor = LinearRegression()
regressor.fit(X_train, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
y_pred = regressor.predict(X_test)
print('Mean Absolute Error:', metrics.mean_absolute_error(y_test, y_pred))
print('Mean Squared Error:', metrics.mean_squared_error(y_test, y_pred))
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(y_test, y_pred)))
# Out:
# Mean Absolute Error: 0.8882883933697403
# Mean Squared Error: 1.6856596063655918
# Root Mean Squared Error: 1.2983295445939724

# %% [markdown]
# ##Generate New Data with coefficient

# %%
coef=Reg_coef.reshape(3,1)
res= np.dot(Final_Data, coef)

# %%
Merge_data=np.concatenate((x_1, Final_Data), axis=0)

# %%
Merge_Labels=np.concatenate((Y_1,res),axis=0)

# %% [markdown]
# ##Train New Model With Merging Data

# %%
X_train, X_test, y_train, y_test = train_test_split(Merge_data,Merge_Labels, test_size=0.2, random_state=0)

# %%
Regress = LinearRegression()
Regress.fit(X_train, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
y_pred = regressor.predict(X_test)

# %%
print('Mean Absolute Error:', metrics.mean_absolute_error(y_test, y_pred))
print('Mean Squared Error:', metrics.mean_squared_error(y_test, y_pred))
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(y_test, y_pred)))
# Out:
# Mean Absolute Error: 1.1583849750644901
# Mean Squared Error: 1.618800035830954
# Root Mean Squared Error: 1.272320728366458

# %%
for i in range (35):
  print(y_test[i])
  print("--------------")
  print(y_pred[i])
# Out:
# [0.04915493]
# --------------
# [1.10445707]
# [0.07333286]
# --------------
# [1.0801169]
# [2.4]
# --------------
# [0.82993466]
# [0.06399904]
# --------------
# [1.19636439]
# [2.5]
# --------------
# [0.97394138]
# [2.23]
# --------------
# [0.99105005]
# [0.12250688]
# --------------
# [0.86218131]
# [3.35]
# --------------
# [0.67237799]
# [0.08233826]
# --------------
# [1.02609391]
# [3.47]
# --------------
# [0.84059416]
# [0.09429423]
# --------------
# [1.02746622]
# [0.06673656]
# --------------
# [1.04791701]
# [3.1]
# --------------
# [0.9807247]
# [0.14629641]
# --------------
# [0.89493209]
# [1.09]
# --------------
# [0.97036594]
# [0.08606674]
# --------------
# [0.93948992]
# [0.07715626]
# --------------
# [1.07642131]
# [0.09347068]
# --------------
# [1.03278679]
# [0.03913848]
# --------------
# [1.28159329]
# [0.10915155]
# --------------
# [0.89376899]
# [0.12246585]
# --------------
# [0.8366416]
# [0.12568293]
# --------------
# [0.99306251]
# [0.12208824]
# --------------
# [1.01035127]
# [0.08629631]
# --------------
# [1.05866589]
# [0.07618262]
# --------------
# [1.02402249]
# [0.08195476]
# --------------
# [1.06397434]
# [0.12337768]
# --------------
# [1.00761382]
# [0.08203977]
# --------------
# [1.03617144]
# [0.11440482]
# --------------
# [1.0107455]
# [3.22]
# --------------
# [0.82346878]
# [0.13710752]
# --------------
# [0.83657844]
# [0.13158756]
# --------------
# [0.69495033]
# [0.14412992]
# --------------
# [0.82705685]
# [3.3]
# --------------
# [0.96973105]
# [3.6]
# --------------
# [0.99298815]

# %% [markdown]
# ##Train Model With Generating Data including Gpa

# %%
data_np= np.array(data)
cov=np.cov(data_np,y=None, rowvar=False, bias=False, ddof=None, fweights=None, aweights=None)
mean=np.mean(data_np,axis=0)
Size_of_Data=242
New_Data= np.random.multivariate_normal(mean, cov,Size_of_Data)
#Function Clean Data Whose Values Are 0
def Delete_Zeros(New_Data):
  index=[]
  for i in New_Data :
    if np.count_nonzero(i == 0) > 0 or np.count_nonzero(i ==( 0)):
        index.append(np.where(np.all(New_Data==i,axis=1))[0][0])
  cleaned_data=np.delete(New_Data,index,0) 
  return cleaned_data

Cleaned_data1=Delete_Zeros(New_Data)
#function Delete rows whose values >6 Days
def constrains_per_day(cleaned_data1):
  x=[]
  for i in range(len(cleaned_data1)):
    if cleaned_data1[i][3]>6:
      x.append(i)  
  cleaned_data2=np.delete(cleaned_data1,x,0)
  return cleaned_data2
Cleaned_data2=constrains_per_day(Cleaned_data1)

#This function delete rows whose Values >10 hours
def constrains_per_hours(Cleaned_data2):
  x=[]
  for i in range(len(Cleaned_data2)):
    if Cleaned_data2[i][2]>10:
      x.append(i)  
  cleaned_data3=np.delete(Cleaned_data2,x,0)
  return cleaned_data3

Cleaned_data3=constrains_per_hours(Cleaned_data2)


#This function delete rows whose values <5 min and >300 min
def constrains_per_min_Road(Cleaned_data3):
  x=[]
  for i in range(len(Cleaned_data3)):
    if Cleaned_data3[i][1]<5 or Cleaned_data3[i][1]>300:
      x.append(i)  
  cleaned_data4=np.delete(Cleaned_data3,x,0)
  return cleaned_data4


def GPA(Cleaned_data):
  x=[]
  for i in range(len(Cleaned_data)):
    if Cleaned_data[i][0]<0 or Cleaned_data[i][0]>4:
      x.append(i)  
  cleaned_data5=np.delete(Cleaned_data,x,0)
  return cleaned_data5

cleaned_data4 = constrains_per_min_Road(Cleaned_data3)
Final_Data1 = GPA(cleaned_data4)

# %%
data_np
# Out:
# array([[  2.04   , 240.     ,   4.     ,   4.     ],
#        [  3.22   , 120.     ,   7.     ,   5.     ],
#        [  2.92   ,  30.     ,   4.     ,   5.     ],
#        [  3.5    ,  60.     ,   5.     ,   4.     ],
#        [  2.86   , 140.     ,   4.     ,   4.     ],
#        [  3.18   ,  70.     ,   6.     ,   5.     ],
#        [  3.     ,   5.     ,   5.     ,   5.     ],
#        [  2.54   , 210.     ,   7.     ,   3.     ],
#        [  3.8    , 200.     ,   4.     ,   1.     ],
#        [  2.6    ,  60.     ,   4.     ,   2.     ],
#        [  2.4    ,  95.     ,   6.     ,   3.     ],
#        [  2.4    , 210.     ,   8.     ,   1.     ],
#        [  2.     , 180.     ,   6.     ,   5.     ],
#        [  3.61   ,   5.     ,   4.     ,   3.     ],
#        [  2.5    ,  85.     ,   4.     ,   4.     ],
#        [  3.1    , 190.     ,   4.     ,   4.     ],
#        [  2.73   , 180.     ,   7.     ,   5.     ],
# 3.07
# 2.7
# 2.8
# 3.12
# 3.27
# 3.1
# 2.75
# 3.04
# 2.85
# 3.45125
# 3.04
# 2.67
# 3.3
# 2.25
# 3.35
# 2.6
# 3.19
# 3.53
# 2.7
# 2.7
# 2.76
# 2.9
# 3.2
# 2.4
# 3.0
# 3.1
# 2.56
# 2.5
# 2.85
# 2.3
# 2.8
# 2.55
# 3.09
# 2.6
# 2.6
# 2.34
# 3.06
# 3.42
# 3.0
# 2.8
# 3.0
# 3.1
# 2.72
# 3.14
# 2.63
# 3.09
# 2.94
# 2.8
# 2.8
# 2.6
# 2.8
# 2.62
# 3.29
# 3.35
# 2.38
# 2.5
# 2.57
# 2.5
# 3.3
# 2.4
# 2.55
# 3.24
# 3.0
# 2.49
# 2.86
# 2.06
# 2.2
# 2.77
# 1.09
# 2.44
# 2.35
# 2.51
# 2.75
# 2.8
# 2.96
# 2.8
# 3.39
# 2.28
# 3.06
# 2.62
# 2.66
# 3.03
# 3.1
# 2.69
# 2.53
# 2.5
# 3.47
# 2.56
# 2.7
# 2.8
# 2.29
# 3.27
# 2.68
# 3.45
# 3.3
# 2.88
# 3.0
# 3.0
# 2.8
# 3.66
# 3.12
# 2.6
# 2.85
# 2.9
# 3.0
# 2.7
# 2.85
# 2.42
# 2.55
# 2.59
# 2.48
# 2.9
# 2.82
# 3.0
# 2.7
# 2.54
# 2.8
# 2.9
# 3.14
# 2.4
# 2.97
# 2.6
# 2.57
# 2.8
# 2.67
# 2.66
# 2.68
# 3.74
# 2.88
# 2.3
# 3.18
# 3.5
# 3.93
# 3.16
# 2.5
# 2.94
# 2.23
# 2.69
# 2.6
# 2.85
# 2.23
# 2.9
# 2.33
# 2.7
# 3.18
# 3.6
# 2.04
# 2.6
# 2.85
# 3.2
# 2.9
# 3.0
# 2.9
# 2.9
# 3.4
# 2.41
# 2.5
# 3.31
# 2.68
# 2.8
# 3.2
# 3.43
# 2.66
# 2.89
# 2.9
# 2.03
# 2.5
# 3.1
# 2.9
# 2.8
# 2.05
# 2.83
# 2.9
# 2.45
# 2.5
# 3.06
# 2.4
# 1.88
# 3.38
# 3.48
# 2.71
# 2.6
# 2.5

# %%
x_2 = Merge_data2[:,1:4]
y_2=Merge_data2[:,0:1]
x_2.shape
#for i in range (1107):
 # print(y_2[i])
# Out:
# (457, 3)

# %%
X_train1, X_test1, y_train1, y_test1 = train_test_split(x_2,y_2, test_size=0.05, random_state=0)

# %%
Regress1 = LinearRegression()
Regress1.fit(X_train1, y_train1)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
y_pred1 = Regress1.predict(X_test1)
#X_test1.shape
y_pred1.shape
# Out:
# (23, 1)

# %%
##zz

# %%
print(X_train1.shape)
print(y_train1.shape)

#y_pred1.shape
# Out:
# (434, 3)
# (434, 1)

# %%
zz = X_test1[:,2]

plt.scatter(zz, y_test1,color='g')
y_pred1.shape
plt.plot(zz, y_pred1,color='r')

# %%
zz = X_train1[:,0]
plt.scatter(zz, y_train1,color='g')
y_pred1.shape
plt.plot(zz, y_train1,color='r')

# %%
  print('Mean Absolute Error:', metrics.mean_absolute_error(y_test1, y_pred1))
print('Mean Squared Error:', metrics.mean_squared_error(y_test1, y_pred1))
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(y_test1, y_pred1)))
# Out:
# Mean Absolute Error: 0.36936160562430786
# Mean Squared Error: 0.18944002481776231
# Root Mean Squared Error: 0.43524708478950475

# %%
#df = pd.DataFrame({'Actual': y_test1[10], 'Predicted': X_test1[0]})
for i in range (23):
  print(y_test1[i])
  print("--------------")
  print(y_pred1[i])
# Out:
# [2.6]
# --------------
# [2.87437672]
# [2.19]
# --------------
# [2.85666869]
# [2.35249666]
# --------------
# [2.90437342]
# [2.9]
# --------------
# [2.8793129]
# [2.7]
# --------------
# [2.83559602]
# [2.74381563]
# --------------
# [2.76122812]
# [2.38227054]
# --------------
# [2.79497349]
# [2.]
# --------------
# [2.85774545]
# [2.88]
# --------------
# [2.83064257]
# [2.62]
# --------------
# [2.76910934]
# [3.]
# --------------
# [2.73030945]
# [2.5]
# --------------
# [2.85652197]
# [3.14]
# --------------
# [2.79928341]
# [2.61]
# --------------
# [2.87070627]
# [2.61464292]
# --------------
# [2.89614323]
# [2.62290644]
# --------------
# [2.81366631]
# [2.4]
# --------------
# [2.84484415]
# [3.57922865]
# --------------
# [2.77765898]
# [3.5]
# --------------
# [2.82881598]
# [3.22933058]
# --------------
# [2.87088118]
# [3.22]
# --------------
# [2.81896475]
# [2.4]
# --------------
# [2.79065759]
# [3.4]
# --------------
# [2.80785165]

# %%
P = [47.77031978,   8.30340601,   5.33225355],
y_pred2 = Regress1.predict(P)
#y_pred2

Reg_coef=Regress1.coef_
Reg_inte=Regress1.intercept_

# %% [markdown]
# ##visualization Error

# %%
visul_merg = Merge_data2.tolist()

# %%
df = pd.DataFrame(visul_merg)
df_1=(df-df.mean())/df.std()

# %%
sb.pairplot(df_1)

# %% [markdown]
# ##Thinking In Tensors_1 **ماعدا العاق عمر محمد **

# %%
#import torch

# %%
# x_features_1 = Merge_data2[:,1:4]
# y_labels_1 = Merge_data2[:,0:1]
# inputs = x_features_1#combined_features_1 #X_1 x_features_1
# targets = y_labels_1#combined_labels_1#Y_1 y_labels_1

# %%
# inputs = torch.from_numpy(inputs)
# targets = torch.from_numpy(targets)

# %%
# print(inputs)
# print(targets)

# %%
# w = torch.randn(1, 3, requires_grad=True)
# b = torch.randn(1, requires_grad=True)

# %%
# inputs.type()

# %%
# def model(x):
#     return x @ w.t() + b

# %%
# preds = model(inputs.float())

# %%
# print(preds)

# %%
# print(targets)

# %%
# def mse(t1, t2):
#     diff = t1 - t2
#     return torch.sum(diff * diff) / diff.numel()

# %%
# loss = mse(preds, targets)
# print(loss)

# %%
# loss.backward()

# %%
# print(w)

# %%
# print(w.grad)

# %%
# print(b)

# %%
# print(b.grad)

# %%
# w.grad.zero_()

# %%
# b.grad.zero_()

# %%
# preds = model(inputs.float())

# %%
# print(preds)

# %%
# loss = mse(preds, targets)

# %%
# print(loss)

# %%
# loss.backward()

# %%
# with torch.no_grad():
#     w -= w.grad * 1e-5
#     b -= b.grad * 1e-5
#     w.grad.zero_()
#     b.grad.zero_()

# %%
# print(w)

# %%
# preds = model(inputs.float())
# loss = mse(preds, targets)
# print(loss)

# %%
# for i in range(40000):
#     preds = model(inputs.float())
#     loss = mse(preds, targets)
#     loss.backward()
#     with torch.no_grad():
#         w -= w.grad * 1e-5
#         b -= b.grad * 1e-5
#         w.grad.zero_()
#         b.grad.zero_()

# %%
# preds = model(inputs.float())
# loss = mse(preds, targets)
# print(loss)

# %%
# preds

# %%
# targets

# %% [markdown]
# ## Thinking In Tensors_2 ( Train Real Data )  **ماعدا العاق عمر محمد **

# %%
import torch
import torch.nn as nn

# %%
inputs_1 = torch.from_numpy(X_1)
targets_1 = torch.from_numpy(Y_1)

# %%
from torch.utils.data import TensorDataset, DataLoader

# %%
train_ds = TensorDataset(inputs_1.float(), targets_1.float())

# %%
train_ds[0:3]
# Out:
# (tensor([[240.,   4.,   4.],
#          [120.,   7.,   5.],
#          [ 30.,   4.,   5.]]), tensor([[2.0400],
#          [3.2200],
#          [2.9200]]))

# %%
batch_size = 5
train_dl = DataLoader(train_ds, batch_size, shuffle=True)
next(iter(train_dl))
# Out:
# [tensor([[240.,  12.,   5.],
#          [ 50.,   8.,   3.],
#          [ 60.,   4.,   2.],
#          [180.,   7.,   5.],
#          [ 60.,   7.,   4.]]), tensor([[2.2900],
#          [3.0400],
#          [2.6000],
#          [2.7300],
#          [3.0700]])]

# %%
model_1 = nn.Linear(3, 1)

# %%
print(model_1.weight)
print(model_1.bias)
# Out:
# Parameter containing:
# tensor([[-0.1497, -0.1741, -0.2863]], requires_grad=True)
# Parameter containing:
# tensor([0.2057], requires_grad=True)

# %%
opt = torch.optim.SGD(model_1.parameters(), lr=1e-5)

# %%
import torch.nn.functional as F

# %%
loss_fn = F.mse_loss

# %%
loss = loss_fn(model_1(inputs_1.float()), targets_1.float())
print(loss)
# Out:
# tensor(783.7346, grad_fn=<MseLossBackward>)

# %%
def fit_1(num_epochs, model, loss_fn, opt):
    for epoch in range(num_epochs):
        for xb,yb in train_dl:
            # Generate predictions
            pred = model(xb)
            loss = loss_fn(pred, yb)
            # Perform gradient descent
            loss.backward()
            opt.step()
            opt.zero_grad()
    print('Training loss: ', loss_fn(model(inputs_1.float()), targets_1.float()))

# %%
fit_1(600, model_1, loss_fn, opt)
# Out:
# Training loss:  tensor(0.3180, grad_fn=<MseLossBackward>)

# %%
preds_1 = model_1(inputs_1.float())
#preds.shape

# %%
print(model_1.weight)
print(model_1.bias)
weights = model_1.weight
bias = model_1.bias
# Out:
# Parameter containing:
# tensor([[0.0014, 0.0997, 0.3291]], requires_grad=True)
# Parameter containing:
# tensor([0.6365], requires_grad=True)

# %%
weights_1 = weights.detach().numpy()
bias_1 = bias.detach().numpy()

# %%
targets_1.shape
# Out:
# torch.Size([242, 1])

# %%
preds_1
# Out:
# tensor([[2.6768],
#         [2.2955],
#         [2.9537],
#         [3.0156],
#         [3.6738],
#         [2.5142],
#         [3.2551],
#         [2.9614],
#         [2.6439],
#         [2.7543],
#         [2.5278],
#         [2.6662],
#         [2.8317],
#         [2.7891],
#         [2.2287],
#         [3.1646],
#         [2.8433],
#         [2.6246],
#         [3.2139],
#         [3.4154],
#         [3.0021],
#         [2.8317],
#         [3.2963],
#         [2.6226],
#         [2.9430],
#         [3.2866],
#         [2.8027],
#         [3.1840],
#         [2.7214],
#         [3.0756],
#         [2.5936],
#         [2.7930],
#         [2.6188],
#         [2.9073],
#         [2.2998],
#         [2.0768],
#         [1.3663],
#         [2.1765],
#         [3.0059],
#         [2.4736],
#         [3.0387],
#         [2.3845],
#         [3.3312],
#         [2.9430],
#         [2.7136],
#         [1.7379],
#         [3.1646],
#         [2.5142],
#         [3.0756],
#         [1.5212],
#         [2.0903],
#         [2.9217],
#         [3.4231],
#         [2.1938],
#         [2.6681],
#         [2.7949],
#         [2.7543],
#         [2.7050],
#         [2.8762],
#         [3.6854],
#         [2.9894],
#         [2.8629],
#         [2.4871],
#         [2.4871],
#         [3.1240],
#         [3.1462],
#         [2.6575],
#         [2.0293],
#         [3.0756],
#         [2.8433],
#         [2.5142],
#         [1.3256],
#         [1.7409],
#         [2.8220]], grad_fn=<AddmmBackward>)

# %%
targets_1[1:6]
# Out:
# tensor([[3.2200],
#         [2.9200],
#         [3.5000],
#         [2.8600],
#         [3.1800]], dtype=torch.float64)

# %%
preds_1[1]
# Out:
# tensor([3.1424], grad_fn=<SelectBackward>)

# %%
targets_1[1]
# Out:
# tensor([3.2200], dtype=torch.float64)

# %%
Final_Data1.shape
# Out:
# (211, 4)

# %% [markdown]
# ## Combine And Generate Labels
#
# 1.   Combine Generate Data And Real Data
# 2.   Get weights and Intercept then Mutliply with Generated data

# %% [markdown]
# **Get weights and Intercept then Mutliply with Generated data**

# %%
Final_Data2 = Final_Data1.tolist()

# %%
fd = pd.DataFrame(Final_Data2)

# %%
fd_1 = fd.drop([0], axis=1)

# %%
fd_1.insert(0, "0", 1)

# %%
Final_Data3 = np.array(fd_1)

# %%
Final_Data3 #generated data
# Out:
# array([[  1.        , 170.01078601,   3.90477838,   3.76278423],
#        [  1.        , 110.19200095,   3.82755638,   4.2454121 ],
#        [  1.        , 163.23470971,   3.52760165,   5.34464867],
#        [  1.        ,  92.69486197,   5.81986699,   3.52854832],
#        [  1.        , 115.3382997 ,   7.49021537,   3.57070626],
#        [  1.        ,  34.63713378,   5.83686318,   3.9143219 ],
#        [  1.        , 131.44043696,   3.33107499,   3.68183459],
#        [  1.        , 133.78031212,   5.581938  ,   3.24530334],
#        [  1.        ,  68.70305423,   5.10432766,   3.38229236],
#        [  1.        ,  13.36904052,   5.32003838,   5.41744078],
#        [  1.        , 140.09625795,   4.12357406,   2.49078787],
#        [  1.        ,  76.05233379,   7.23676193,   4.86712442],
#        [  1.        ,  49.55477873,   5.66594644,   3.6730146 ],
#        [  1.        ,  42.08753547,   4.72492437,   4.48251053],
#        [  1.        ,  59.45525393,   5.20466531,   2.94544204],
#        [  1.        , 231.09860746,   6.17199395,   3.75045838]])

# %%
weights_1
# Out:
# array([[0.00135464, 0.09970117, 0.3290942 ]], dtype=float32)

# %%
ws1 = weights_1[0][0]
ws2 = weights_1[0][1]
ws3 = weights_1[0][2]
bs = bias_1[0]

# %%
betas = np.array([bs,ws1,ws2,ws3])
betas
# Out:
# array([0.63648105, 0.00135464, 0.09970117, 0.3290942 ], dtype=float32)

# %%
new_Gpas = np.dot(Final_Data3,betas)
new_Gpas_shape = new_Gpas.shape[0]

# %%
new_Gpas = np.reshape(new_Gpas,(new_Gpas_shape,1))

# %% [markdown]
#   **combine between Generated data and Real Data**

# %%
fd_2 = pd.DataFrame(Final_Data2)
fd_3 = fd.drop([0], axis=1)

# %%
gen_1 = np.array(fd_3)

# %%
combined_features_1  = np.concatenate((X_1,gen_1), axis=0)

# %%
combined_labels_1 =np.concatenate((Y_1,new_Gpas), axis=0)

# %% [markdown]
# ## Thinking In Tensors_2 ( Train Real Data And Generated Data )  **ماعدا العاق عمر محمد **

# %%
inputs = torch.from_numpy(combined_features_1)
targets = torch.from_numpy(combined_labels_1)

# %%
train_ds = TensorDataset(inputs.float(), targets.float())

# %%
train_ds[0:3]
# Out:
# (tensor([[240.,   4.,   4.],
#          [120.,   7.,   5.],
#          [ 30.,   4.,   5.]]), tensor([[2.0400],
#          [3.2200],
#          [2.9200]]))

# %%
batch_size = 5
train_dl = DataLoader(train_ds, batch_size, shuffle=True)
next(iter(train_dl))
# Out:
# [tensor([[  5.0000,   5.0000,   5.0000],
#          [181.0517,   2.5612,   4.6784],
#          [191.6098,   6.5172,   3.0758],
#          [ 60.0000,   6.0000,   3.0000],
#          [  5.0000,   6.0000,   4.0000]]), tensor([[3.0000],
#          [2.6767],
#          [2.5580],
#          [2.4200],
#          [2.6900]])]

# %%
model = nn.Linear(3, 1)

# %%
opt = torch.optim.SGD(model.parameters(), lr=1e-5)

# %%
loss_fn = F.mse_loss

# %%
loss = loss_fn(model(inputs.float()), targets.float())
loss.type()
# Out:
# 'torch.FloatTensor'

# %%
def fit(num_epochs, model, loss_fn, opt):
    for epoch in range(num_epochs):
        for xb,yb in train_dl:
            # Generate predictions
            pred = model(xb)
            loss = loss_fn(pred, yb)
            # Perform gradient descent
            loss.backward()
            opt.step()
            opt.zero_grad()
    print('Training loss: ', loss_fn(model(inputs.float()), targets.float()))

# %%
fit(400, model, loss_fn, opt)
# Out:
# Training loss:  tensor(0.1657, grad_fn=<MseLossBackward>)

# %%
preds = model(inputs.float())
#preds.shape

# %%
print(model.weight)
print(model.bias)
# Out:
# Parameter containing:
# tensor([[0.0015, 0.0957, 0.3190]], requires_grad=True)
# Parameter containing:
# tensor([0.7083], requires_grad=True)

# %%
preds[1]
# Out:
# tensor([3.1511], grad_fn=<SelectBackward>)

# %%
targets[1]
# Out:
# tensor([3.2200], dtype=torch.float64)
